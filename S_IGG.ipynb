# %%
library(immunarch)  # Load the package into R
immdata <- repLoad("/corgi/martin/R/S_IGG/")
# Out:
# Loading required package: ggplot2
#
# Loading required package: dplyr
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: dtplyr
#
# Loading required package: data.table
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# Loading required package: patchwork
#
#
# == Step 1/3: loading repertoire files... ==
#
#
# Processing "/corgi/martin/R/S_IGG/" ...
#
#   -- [1/3] Parsing "/corgi/martin/R/S_IGG//S1_IGG.txt" --
# mixcr
#
#   -- [2/3] Parsing "/corgi/martin/R/S_IGG//S3_IGG.txt" --
# mixcr
#
#   -- [3/3] Parsing "/corgi/martin/R/S_IGG//S4_IGG.txt" --
# mixcr
#
#
# == Step 2/3: checking metadata files and merging files... ==
#
#
# Processing "/corgi/martin/R/S_IGG/" ...
#
# ...

# %%
target <- c("CAYTPSWSSRYYFAHW", "CARDTLRFLEWKYPGPDYFYYYMDVW", "CSRGGRSQSRRDYLGYVGHW", "CARAATPRSYFYYMDVW", "CTTDMPLGPGGGIMNLHRGFDPW", "CARGERGLLDAFDIW", "CARGFGYDFWEGWFDLW", "CAKDRRDIFDNSGDAFDLW", "CARLRPQYCTNDICYLFFDYW", "CARGGRGLGLVDGVGDAFDVW", "CASGARRHGQW", "CARGGGGVNVVAPSTRVLRHW", "CLPSGGWSRW", "CARGERGLLDAFDIW", "CARGFGYDFWEGWFDLW")
tc <- trackClonotypes(immdata$data, target, .col = "aa")
p <- vis(tc)
p
# Out:
# Warning message in melt.data.table(.data):
# “id.vars and measure.vars are internally guessed when both are 'NULL'. All non-numeric/integer/logical type columns are considered id.vars, which in this case are columns [CDR3.aa]. Consider providing at least one of 'id' or 'measure' vars in future.”
# plot without title
