# %%
library(immunarch)  # Load the package into R
immdata <- repLoad("/corgi/martin/R/light_chains/")
# Out:
# Loading required package: ggplot2
#
# Loading required package: dplyr
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: dtplyr
#
# Loading required package: data.table
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# Loading required package: patchwork
#
#
# == Step 1/3: loading repertoire files... ==
#
#
# Processing "/corgi/martin/R/light_chains/" ...
#
#   -- [1/18] Parsing "/corgi/martin/R/light_chains//N1_IGK.txt" --
# mixcr
#
#   -- [2/18] Parsing "/corgi/martin/R/light_chains//N1_IGL.txt" --
# mixcr
#
#   -- [3/18] Parsing "/corgi/martin/R/light_chains//N3_IGK.txt" --
# mixcr
#
#   -- [4/18] Parsing "/corgi/martin/R/light_chains//N3_IGL.txt" --
# mixcr
#
#   -- [5/18] Parsing "/corgi/martin/R/light_chains//N4_IGK.txt" --
# mixcr
#
#   -- [6/18] Parsing "/corgi/martin/R/light_chains//N4_IGL.txt" --
# mixcr
#
#   -- [7/18] Parsing "/corgi/martin/R/light_chains//P1_IGK.txt" --
# mixcr
#
#   -- [8/18] Parsing "/corgi/martin/R/light_chains//P1_IGL.txt" --
# mixcr
#
# Warning message:
# “One or more parsing issues, see `problems()` for details”
#   -- [9/18] Parsing "/corgi/martin/R/light_chains//P3_IGK.txt" --
# mixcr
#
#   -- [10/18] Parsing "/corgi/martin/R/light_chains//P3_IGL.txt" --
# mixcr
#
#   -- [11/18] Parsing "/corgi/martin/R/light_chains//P4_IGK.txt" --
# mixcr
#
#   -- [12/18] Parsing "/corgi/martin/R/light_chains//P4_IGL.txt" --
# mixcr
#
#   -- [13/18] Parsing "/corgi/martin/R/light_chains//S1_IGK.txt" --
# mixcr
#
#   -- [14/18] Parsing "/corgi/martin/R/light_chains//S1_IGL.txt" --
# mixcr
#
#   -- [15/18] Parsing "/corgi/martin/R/light_chains//S3_IGK.txt" --
# mixcr
#
#   -- [16/18] Parsing "/corgi/martin/R/light_chains//S3_IGL.txt" --
# mixcr
#
#   -- [17/18] Parsing "/corgi/martin/R/light_chains//S4_IGK.txt" --
# mixcr
#
#   -- [18/18] Parsing "/corgi/martin/R/light_chains//S4_IGL.txt" --
# mixcr
#
#
# == Step 2/3: checking metadata files and merging files... ==
#
#
# Processing "/corgi/martin/R/light_chains/" ...
#
#   -- Metadata file not found; creating a dummy metadata...
#
#
# == Step 3/3: processing paired chain data... ==
#
#
# Done!

# %%
exp_vol <- repExplore(immdata$data, .method = "volume")
p1 <- vis(exp_vol)
p1
# Out:
# plot without title

# %%
exp_vol <- repExplore(immdata$data, .method = "volume")
by_vec <- c("N_K", "N_L", "N_K", "N_L", "N_K", "N_L", "P_K", "P_L", "P_K", "P_L", "P_K", "P_L", "S_K", "S_L", "S_K", "S_L", "S_K", "S_L")
p <- vis(exp_vol, .by = by_vec, .test = F)
p
# Out:
# plot without title

# %%
exp_vol <- repExplore(immdata$data, .method = "volume")
by_vec <- c("N_K", "N_L", "N_K", "N_L", "N_K", "N_L", "P_K", "P_L", "P_K", "P_L", "P_K", "P_L", "S_K", "S_L", "S_K", "S_L", "S_K", "S_L")
b <- vis(exp_vol, .by = by_vec, .test = F)
ggsave(filename = "clono_KL.png", plot = b, width = 5, height = 6)
b
# Out:
# plot without title

# %%
# Compute statistics and visualise them
# Chao1 diversity measure
div_chao <- repDiversity(immdata$data, "chao1")

# Hill numbers
div_hill <- repDiversity(immdata$data, "hill")

# D50
div_d50 <- repDiversity(immdata$data, "d50")

# Ecological diversity measure
div_div <- repDiversity(immdata$data, "div")

p1 <- vis(div_chao)
p2 <- vis(div_hill)
p3 <- vis(div_d50)
p4 <- vis(div_div)

p1
p2
p3
p4
# Out:
# plot without title
# plot without title
# plot without title
# plot without title

# %%
div_d50 <- repDiversity(immdata$data, "d50")
by_vec <- c("N_K", "N_L", "N_K", "N_L", "N_K", "N_L", "P_K", "P_L", "P_K", "P_L", "P_K", "P_L", "S_K", "S_L", "S_K", "S_L", "S_K", "S_L")
p <- vis(div_d50, .by = by_vec, .test = F)
p
# Out:
# plot without title

# %%
imm_ov1 <- repOverlap(immdata$data, .method = "public", .verbose = F)
imm_ov2 <- repOverlap(immdata$data, .method = "morisita", .verbose = F)

p1 <- vis(imm_ov1)
p2 <- vis(imm_ov2, .text.size = 2)

p1
p2
# Out:
# plot without title
# plot without title

# %%
pr_aav_cod <- pubRep(immdata$data, "aa+v", .coding = T, .verbose = F)
pr_aav_cod
# Out:
#       CDR3.aa         V.name                      Samples N1_IGK N1_IGL N3_IGK
# 1     CAAWDDSLNGLYVF  IGLV1-44, IGLV1-47          9       NA      2     NA
# 2     CAAWDDSLNGPVF   IGLV1-44, IGLV1-47          9       NA     23     NA
# 3     CAAWDDSLNGVVF   IGLV1-44, IGLV1-47          9       NA     10     NA
# 4     CAAWDDSLSGPWVF  IGLV1-47, IGLV1-44          9       NA      2     NA
# 5     CAAWDDSLSGRVF   IGLV1-47, IGLV1-44          9       NA      5     NA
# 6     CAAWDDSLSGVVF   IGLV1-47, IGLV1-44          9       NA     13     NA
# 7     CAAWDDSLSGWVF   IGLV1-47, IGLV1-44          9       NA     27     NA
# 8     CCSYAGSSTWVF    IGLV2-23                    9       NA     68     NA
# 9     CCSYAGSSTYVF    IGLV2-23                    9       NA     16     NA
# 10    CCSYAGSYTFVVF   IGLV2-11, IGLV2-8           9       NA      4     NA
# 11    CCSYAGSYTLVF    IGLV2-11, IGLV2-8           9       NA      7     NA
# 12    CGADHGSGSNFVYVF IGLV9-49                    9       NA      1     NA
# 13    CGTWDSSLSAGVF   IGLV1-51                    9       NA     10     NA
# 14    CGTWDSSLSAVVF   IGLV1-51                    9       NA     11     NA
# 15    CLQHNSYPRTF     IGKV1-17, IGKV1-6, IGKV1-9  9        2     NA     15
# 16    CLQHNSYPWTF     IGKV1-17, IGKV1-6, IGKV1-9  9        2     NA      2
# 17    CMIWHSSAWVF     IGLV5-45                    9       NA     26     NA
# 18    CMQALQTPITF     IGKV2-28                    9        6     NA      5
# 19    CMQALQTPLTF     IGKV2-28                    9       29     NA     12
# 20    CMQALQTPPTF     IGKV2-28                    9        9     NA      3
# 21    CMQALQTPRTF     IGKV2-28                    9       20     NA      2
# 22    CMQALQTPTF      IGKV2-28                    9        3     NA      4
# 23    CMQALQTPWTF     IGKV2-28                    9       11     NA      8
# 24    CMQALQTPYTF     IGKV2-28                    9       14     NA      6
# 25    CMQGTHWPLTF     IGKV2-30                    9        4     NA      2
# 26    CMQGTHWPWTF     IGKV2-30                    9        2     NA     11
# 27    CNSRDSSGNHLGVF  IGLV3-19                    9       NA      9     NA
# 28    CNSRDSSGNHLVF   IGLV3-19                    9       NA      5     NA
# 29    CNSRDSSGNHWVF   IGLV3-19                    9       NA      7     NA
# 30    CQAWDSSTAVF     IGLV3-1                     9       NA     13     NA
# ⋮     ⋮               ⋮                           ⋮       ⋮      ⋮      ⋮
# 36237 RSSYTSSSTPVF    IGLV2-14, IGLV2-11, IGLV2-8 1       NA     NA     NA
# 36238 SCSYTNSATWVF    IGLV2-5                     1       NA     NA     NA
# 36239 SCSYTSSATHWVF   IGLV2-5                     1       NA      1     NA
# 36240 SFSRQWNWLF      IGLV3-16                    1       NA     NA     NA
# 36241 SLAWDTSLSHWVF   IGLV1-41                    1       NA     NA     NA
# 36242 SQQYDSFPQKTF    IGKV1-8, IGKV1-9, IGKV1-12  1        1     NA     NA
# 36243 SQQYNNWSTF      IGKV3-15                    1       NA     NA     NA
# 36244 SQSFDSSTVIF     IGLV6-57                    1       NA     NA     NA
# 36245 SQSYDSSLSGVVF   IGLV1-40, IGLV1-50          1       NA      1     NA
# 36246 SQVWGSGTARVF    IGLV3-29                    1       NA     NA     NA
# 36247 SSSYARTTFRVF    IGLV2-14, IGLV2-8, IGLV2-11 1       NA     NA     NA
# 36248 TAVVLMVF        IGLV3-16                    1       NA     NA     NA
# 36249 WGITF           IGKV1-33                    1       NA     NA     NA
# 36250 WQQYDNLPPGLTF   IGKV1-33                    1       NA     NA     NA
# 36251 WQSYDSSLNSWVF   IGLV1-40, IGLV1-50          1       NA     NA     NA
# 36252 YCQQSYRTPLTF    IGKV1-39                    1       NA     NA     NA
# 36253 YCSSNAGTYTWVF   IGLV2-11, IGLV2-8, IGLV2-18 1       NA     NA     NA
# 36254 YCSTDSRIKHGWVF  IGLV3-10                    1       NA     NA     NA
# 36255 YCSYTGSATWLF    IGLV2-5                     1       NA     NA     NA
# 36256 YFFSYTTTRNWVF   IGLV7-46                    1       NA     NA     NA
# 36257 YFSASDNNLGLF    IGLV3-27                    1       NA     NA     NA
# 36258 YGAF            IGLV9-49                    1       NA     NA     NA
# 36259 YMLGTHWLWTF     IGKV2-30                    1        1     NA     NA
# 36260 YMQGLQTRLTF     IGKV2-28                    1       NA     NA     NA
# 36261 YNNWPPWTF       IGKV3-15                    1       NA     NA     NA
# 36262 YQQANSFPRNF     IGKV1-12, IGKV1-16, IGKV1-9 1       NA     NA     NA
# 36263 YQSFDNSTVIF     IGLV6-57                    1       NA     NA     NA
# 36264 YTSHTNKSTFDVF   IGLV2-18, IGLV2-11, IGLV2-8 1       NA     NA     NA
# 36265 YYSAADNILGVF    IGLV3-27                    1       NA     NA     NA
# 36266 YYSYAGSSTLVF    IGLV2-23                    1       NA     NA     NA
#       N3_IGL N4_IGK N4_IGL P1_IGK ⋯ P3_IGK P3_IGL P4_IGK P4_IGL S1_IGK S1_IGL
# 1      4      NA     2      NA    ⋯ NA      10    NA      1     NA      4
# 2     17      NA    17      NA    ⋯ NA     104    NA      1     NA      4
# 3     16      NA    27      NA    ⋯ NA      90    NA     34     NA      6
# 4      1      NA     4      NA    ⋯ NA      15    NA      1     NA      1
# 5     11      NA    11      NA    ⋯ NA      81    NA      4     NA      4
# 6      9      NA    36      NA    ⋯ NA      77    NA     23     NA     12
# 7     25      NA    26      NA    ⋯ NA     184    NA     21     NA      3
# 8     45      NA    33      NA    ⋯ NA     260    NA     17     NA      4
# 9     16      NA    35      NA    ⋯ NA     156    NA      9     NA     68
# 10     3      NA    34      NA    ⋯ NA      11    NA      2     NA      2
# 11     3      NA     6      NA    ⋯ NA      34    NA      8     NA      2
# 12     1      NA     3      NA    ⋯ NA      19    NA      4     NA      2
# 13     5      NA    15      NA    ⋯ NA     107    NA      9     NA      1
# 14     2      NA    25      NA    ⋯ NA      49    NA     31     NA      2
# 15    NA       6    NA      23    ⋯ 20      NA     2     NA      5     NA
# 16    NA       7    NA       9    ⋯ 35      NA     2     NA      1     NA
# 17     4      NA     1      NA    ⋯ NA      85    NA      2     NA      1
# 18    NA       5    NA      46    ⋯ 32      NA     4     NA      3     NA
# 19    NA      23    NA     129    ⋯ 84      NA    29     NA     11     NA
# 20    NA      18    NA      84    ⋯ 50      NA    20     NA      2     NA
# 21    NA      36    NA      97    ⋯ 58      NA    17     NA      2     NA
# 22    NA       7    NA      36    ⋯ 17      NA     7     NA      3     NA
# 23    NA      22    NA      70    ⋯ 51      NA    27     NA     14     NA
# 24    NA     478    NA      67    ⋯ 60      NA    22     NA     15     NA
# 25    NA       6    NA      20    ⋯ 21      NA     5     NA     69     NA
# 26    NA       4    NA      27    ⋯ 25      NA     3     NA      2     NA
# 27     2      NA     1      NA    ⋯ NA      31    NA      3     NA      1
# 28     6      NA    14      NA    ⋯ NA      60    NA      8     NA      3
# 29     8      NA     1      NA    ⋯ NA      38    NA      2     NA      1
# 30     2      NA    19      NA    ⋯ NA      28    NA     10     NA      6
# ⋮     ⋮      ⋮      ⋮      ⋮      ⋱ ⋮      ⋮      ⋮      ⋮      ⋮      ⋮
# 36237 NA     NA     NA     NA     ⋯ NA     NA     NA     NA     NA     NA
# 36238 NA     NA     NA     NA     ⋯ NA     NA     NA     NA     NA     NA
# 36239 NA     NA     NA     NA     ⋯ NA     NA     NA     NA     NA     NA
# 36240  1     NA     NA     NA     ⋯ NA     NA     NA     NA     NA     NA
# 36241 NA     NA     NA     NA     ⋯ NA     NA     NA     NA     NA     NA
# 36242 NA     NA     NA     NA     ⋯ NA     NA     NA     NA     NA     NA
# 36243 NA     NA     NA      1     ⋯ NA     NA     NA     NA     NA     NA
# 36244 NA     NA     NA     NA     ⋯ NA     NA     NA     NA     NA     NA
# 36245 NA     NA     NA     NA     ⋯ NA     NA     NA     NA     NA     NA
# 36246 NA     NA     NA     NA     ⋯ NA     NA     NA     NA     NA     NA
# 36247 NA     NA     NA     NA     ⋯ NA     NA     NA     NA     NA     NA
# 36248 NA     NA     NA     NA     ⋯ NA     NA     NA     NA     NA     NA
# 36249 NA     NA     NA     NA     ⋯  1     NA     NA     NA     NA     NA
# 36250 NA     NA     NA      1     ⋯ NA     NA     NA     NA     NA     NA
# 36251 NA     NA     NA     NA     ⋯ NA     NA     NA     NA     NA     NA
# 36252 NA      1     NA     NA     ⋯ NA     NA     NA     NA     NA     NA
# 36253 NA     NA     NA     NA     ⋯ NA     NA     NA     NA     NA     NA
# 36254 NA     NA     NA     NA     ⋯ NA     NA     NA     NA     NA     NA
# 36255 NA     NA     NA     NA     ⋯ NA     NA     NA     NA     NA     NA
# 36256 NA     NA      1     NA     ⋯ NA     NA     NA     NA     NA     NA
# 36257 NA     NA     NA     NA     ⋯ NA     NA     NA     NA     NA     NA
# 36258 NA     NA     NA     NA     ⋯ NA      1     NA     NA     NA     NA
# 36259 NA     NA     NA     NA     ⋯ NA     NA     NA     NA     NA     NA
# 36260 NA     NA     NA      1     ⋯ NA     NA     NA     NA     NA     NA
# 36261 NA     NA     NA      1     ⋯ NA     NA     NA     NA     NA     NA
# 36262 NA     NA     NA     NA     ⋯ NA     NA     NA     NA     NA     NA
# 36263 NA     NA     NA     NA     ⋯ NA     NA     NA     NA     NA     NA
# 36264 NA     NA     NA     NA     ⋯ NA     NA     NA     NA     NA     NA
# 36265 NA     NA     NA     NA     ⋯ NA     NA     NA     NA     NA     NA
# 36266 NA     NA     NA     NA     ⋯ NA      1     NA     NA     NA     NA
#       S3_IGK S3_IGL S4_IGK S4_IGL
# 1      NA      8     NA     2
# 2      NA     63     NA    18
# 3      NA     79     NA    33
# 4      NA      7     NA     3
# 5      NA     48     NA    12
# 6      NA    146     NA    35
# 7      NA    144     NA    54
# 8      NA    562     NA    36
# 9      NA    222     NA    15
# 10     NA     14     NA     7
# 11     NA      1     NA     8
# 12     NA     10     NA     2
# 13     NA     99     NA    28
# 14     NA     57     NA    11
# 15     23     NA      2    NA
# 16     20     NA      7    NA
# 17     NA     62     NA     5
# 18     26     NA      9    NA
# 19     98     NA     53    NA
# 20     59     NA     10    NA
# 21     47     NA    129    NA
# 22     20     NA     10    NA
# 23    208     NA     24    NA
# 24     41     NA     26    NA
# 25      9     NA      9    NA
# 26     20     NA     18    NA
# 27     NA     30     NA     4
# 28     NA     90     NA    14
# 29     NA     35     NA     1
# 30     NA     22     NA    13
# ⋮     ⋮      ⋮      ⋮      ⋮
# 36237 NA     NA     NA     NA
# 36238 NA      4     NA     NA
# 36239 NA     NA     NA     NA
# 36240 NA     NA     NA     NA
# 36241 NA     NA     NA     NA
# 36242 NA     NA     NA     NA
# 36243 NA     NA     NA     NA
# 36244 NA      4     NA     NA
# 36245 NA     NA     NA     NA
# 36246 NA     NA     NA     NA
# 36247 NA     NA     NA     NA
# 36248 NA     NA     NA     NA
# 36249 NA     NA     NA     NA
# 36250 NA     NA     NA     NA
# 36251 NA      2     NA     NA
# 36252 NA     NA     NA     NA
# 36253 NA     NA     NA     NA
# 36254 NA     NA     NA     NA
# 36255 NA      1     NA     NA
# 36256 NA     NA     NA     NA
# 36257 NA      1     NA     NA
# 36258 NA     NA     NA     NA
# 36259 NA     NA     NA     NA
# 36260 NA     NA     NA     NA
# 36261 NA     NA     NA     NA
# 36262 NA     NA      1     NA
# 36263 NA      2     NA     NA
# 36264 NA     NA     NA     NA
# 36265 NA      1     NA     NA
# 36266 NA     NA     NA     NA

# %%
imm_ov1 <- repOverlap(immdata$data, .method = "public", .verbose = F)
imm_ov2 <- repOverlap(immdata$data, .method = "morisita", .verbose = F)
imm_ov3 <- repOverlap(immdata$data, .method = "jaccard", .verbose = F)
imm_ov4 <- repOverlap(immdata$data, .method = "overlap", .verbose = F)
imm_ov5 <- repOverlap(immdata$data, .method = "tversky", .verbose = F)
imm_ov6 <- repOverlap(immdata$data, .method = "cosine", .verbose = F)

# %%
library("RColorBrewer")
p1 <- vis(imm_ov1, "heatmap2", .title = "", text.size = 10, .color = colorRampPalette(brewer.pal(n = 7, name = "Blues"))(100))
p1 
ggsave(filename = "FIGURE_overlap_light.png", plot = p1, width = 4.8, height = 4.5, dpi = 600)
# Out:
# plot without title

# %%
target <- c("CQQYYSTPWTF", "CQQYNSYPYTF", "CQQSYSAPPTF", "CQQTYSTPRTF", "CQQYNNWPPWTF", "CQQYYSTPLTF", "CQQYYSTLSLTF", "CQQSYSTPITF", "CQQYNYWPRTF", "CQQRSNWPLTF", "CQQSYSTPQTF", "CQQYNSYPWTF", "CMQALQTPRTF", "CQQYGSSPITF", "CLQYNTYPQYTF")
tc <- trackClonotypes(immdata$data, target, .col = "aa")
p <- vis(tc)
p
# Out:
# Warning message in melt.data.table(.data):
# “id.vars and measure.vars are internally guessed when both are 'NULL'. All non-numeric/integer/logical type columns are considered id.vars, which in this case are columns [CDR3.aa, ...]. Consider providing at least one of 'id' or 'measure' vars in future.”
# Warning message:
# “`spread_()` was deprecated in tidyr 1.2.0.
# Please use `spread()` instead.
# This warning is displayed once every 8 hours.
# Call `lifecycle::last_lifecycle_warnings()` to see where this warning was generated.”
# Warning message:
# “The `.dots` argument of `group_by()` is deprecated as of dplyr 1.0.0.
# This warning is displayed once every 8 hours.
# Call `lifecycle::last_lifecycle_warnings()` to see where this warning was generated.”
# plot without title
